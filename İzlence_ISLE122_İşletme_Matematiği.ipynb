# %% [markdown]
# <a href="https://colab.research.google.com/github/MMBAYAR/IMAT23/blob/main/%C4%B0zlence_ISLE122_%C4%B0%C5%9Fletme_Matemati%C4%9Fi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# ***
# > # **ISLE122 - İşletme Matematiği'ne**
# >> # **Hoşgeldiniz !**
# ***
# ***
# - ### **Dersin Sorumlusu :**
#  - ### Mustafa Mehmet BAYAR, Ph.D.
# - ### **Öğrenci Görüşme Saatleri:**
#  - ### bkz. İşletme Bölümü Oda 212'nin *Duyurular Tahtası*
# ***
# ***
# - ### **Dersin Gereği Olarak Yapılacak Okumalar :**
#  - ### Haftalık Ders Notları
# - ### **Önerilen Okumalar :**
#  - ### Don, E., & Lerner, J. J. (1999). Schaum's outline of basic business mathematics. Schaum's Outline Series.
#  - ### Lipschutz, S., & Lipson, M. (1997). Discrete Mathematics, Schaum’s Outlines.
#  - ### 3Blue1Brown YouTube Kanalı:
#  https://www.youtube.com/c/3blue1brown
#  - ### MIT Açık Ders Kaynakları:
#  https://ocw.mit.edu/courses/18-01-single-variable-calculus-fall-2006/
# - ### **Yardımcı Ders Materyali :**
#  - ### Grafik Hesap Makinesi:
#  https://www.desmos.com/calculator?lang=tr
#  - ### Python Kodlama Ortamı:
#  https://colab.research.google.com/
# ***
# ***
# - ### **Notlama Politikası :**
#  - ### **Ödevler**
# > ### Bu derste 6'sı ara sınav öncesi, 6'ı ara sınav sonrası olmak üzere toplam 12 ödev olacaktır.Bu ödevler ders notunuzu$^1$ will ***ciddi biçimde etkileyecektir***.
# > ### Uygun biçemde hazırlanmış ve zamanında teslim edilmiş ödevler için ***en düşük not*** 100 üzerinden 30 puandır. Geç teslimlerde (*48 saate kadar*) veya biçem kurallarına uyulmayan teslimler için ise ***en yüksek not*** 100 üzerinden 70 puandır.
# > ### 48 saatten sonra yapılan hiçbir ödev teslimi ***dikkate alınmayacaktır*** (istisna yoktur).
#  - ### **Harf Notu**
# > ### bkz. ANKARA HACI BAYRAM VELİ ÜNİVERSİTESİ ÖN LİSANS-LİSANS EĞİTİM-ÖĞRETİM VE SINAV YÖNETMELİĞİ$^{2}$ \ Bölüm 5 \ Madde 24
#  - ### **Devamsızlık**
# > ### bkz. ANKARA HACI BAYRAM VELİ ÜNİVERSİTESİ ÖN LİSANS-LİSANS EĞİTİM-ÖĞRETİM VE SINAV YÖNETMELİĞİ \ Bölüm 3 \ Madde 15
# ***
# ( $^1$ ): Ara sınavdan önce 1 ve ara sınavdan sonra 1 en düşüklü notlanmış iki ödev notlamaya dahil edilmeyecektir.
# ***
# ( $^{2}$ ): *https://www.mevzuat.gov.tr/mevzuat?MevzuatNo=33750&MevzuatTur=8&MevzuatTertip=5*
# ***
# ***
# - ### **Öngörülen Ders Planı :**
#
# \begin{array}{lcl}
# Hafta\ 1 & : & {Hatasız\ bir\ makine\ olarak\ fonksiyon:\\ \ \ \ \ Bağıntı\ ve\ fonksiyon\ kavramlarına\ dair\ kısa\ bir\ ders} \\
# Hafta\ 2 & : & {Fonksiyonların\ grafiği\ ve\ değişim\ hızı\ kavramı \\
# {\begin{array}{ll}
# • & Fonksiyonun\ yönü,\\
# • & Fonksiyonun\ bükümü,\\
# • & Limitten\ türeve\ olan\ yolculuk \\
# \end{array}}} \\
# Hafta\ 3 & : & {Tek\ değişkenli\ fonksiyonlarda\ türev\ bilgisi \\
# {\begin{array}{ll}
# • & Optimizasyon\ ve\ aramaya\ giriş,\\
# • & Maksimizasyon\ ve\ minimizasyon\ problem\ örnekleri,\\
# • & {Birinci\ türev\ bilgisi,\ ikinci\ türev\ bilgisi\\ ve\ optimizasyon\ problemlerinde\ çözüm\ stratejileri} \\
# \end{array}}} \\
# Hafta\ 4 & : & {Tek\ değişkenli\ fonksiyonlarda\ türev\ bilgisi\ (devam) \\
# {\begin{array}{ll}
# • & Grafik\ yöntem\ ile\ çözüm, \\
# • & Maksimizasyon\ ve\ minimizasyon\ problem\ örnekleri,\\
# • & {Birinci\ türev\ bilgisi,\ ikinci\ türev\ bilgisi\\ ve\ optimizasyon\ problemlerinde\ çözüm\ stratejileri} \\
# \end{array}}} \\
# Hafta\ 5 & : & {Temel\ türev\ alma\ kuralları \\
# {\begin{array}{ll}
# • & Elde\ hesaplama, \\
# • & Bilgisayar\ ile\ hesaplama,\\
# • & Uygulama\ problemleri \\\end{array}}}\\
# Hafta\ 6 & : & Uygulama\ problemleri \\
# Hafta\ 7 & : & Uygulama\ problemleri \\
# Hafta\ 8 & : & Dönem-Arası\  Sınavları \\
# Hafta\ 9 & : & {Çok\ değişkenli\ fonksiyonlarda\ türev\ bilgisi \\
# {\begin{array}{ll}
# • & Temel\ kavramlar:\\
#  - & \ \ \ \ Gradyan\ vektörü,\\
#  - & \ \ \ \ Çoklu\ görüntü\ ve\ Jacobean\ matrisi,\\
#  - & \ \ \ \ Hessian\ matrisi\ ve\ pozitif\ yarı\ tanımlılık,\\
# • & Çok\ değişkenli\ fonksiyon\ örnekleri,\\
# • & {Birinci\ türev\ bilgisi,\ ikinci\ türev\ bilgisi\\ ve\ optimizasyon\ problemlerinde\ çözüm\ stratejileri} • & Karmaşıklık\ düzeyi \\
# \end{array}}} \\
# Hafta\ 10 & : & Uygulama\ problemleri \\
# Hafta\ 11 & : & Kritik\ nokta\ türleri\ ve\ ikinci\ türev\ testi: \\
# & & {\begin{array}{ll}
# • & Neden\ umurumuzda,\\
# • & Uygulama\ problemleri,\\
# • & İkinci\ türev\ bilgisinin\ maliyeti \\
# \end{array}} \\
# Hafta\ 12 & : & Doğrusal\ Cebirin\ Temel\ Kavramları \\
# & & {\begin{array}{ll}
# • & Skalar, \\
# • & Vektör,\\
# • & Matris, \\
# • & Tensör \\
# \end{array}} \\
# Hafta\ 13 & : & Vektör\ işlemleri: \\
# & & {\begin{array}{ll}
# • & Toplamsal\ işlemler, \\
# • & Çarpımsal\ işlemler,\\
# • & Matris\ çarpımı, \\
# • & Vektör\ çarpımı \\
# \end{array}} \\
# Hafta\ 14 & : & Matris\ işlemleri: \\
# & & {\begin{array}{ll}
# • & Tekillik, \\
# • & Matrisin\ tersi,\\
# • & Matris\ çarpımı, \\
# • & Doğrusal\ eşitlikler\ sistemleri \\
# \end{array}} \\
# Hafta\ 15 & : & Uygulama\ problemleri \\
# Hafta\ 16 & : & Dönem-Sonu\ Sınavları \\
# \end{array}
# ***
# ***
